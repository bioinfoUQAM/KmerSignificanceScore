# %%
import os
import subprocess
from Bio import SeqIO, AlignIO
from Bio.SeqRecord import SeqRecord
from collections import defaultdict
from Bio.Align import AlignInfo

# %%
def write_temp_fasta(records, filepath):
    """
    Write a list of SeqRecord objects to a FASTA file.

    Parameters:
    records (list of SeqRecord): List of sequence records to write to the file.
    filepath (str): Path to the output FASTA file.
    """
    SeqIO.write(records, filepath, "fasta")

# %%
def process_sequences_by_class(input_fasta):
    """
    Parse sequences from a FASTA file and group them by class.

    Assumes that the class label is the last item in the description, separated by '|'.

    Parameters:
    input_fasta (str): Path to the input FASTA file containing sequences.

    Returns:
    dict: A dictionary mapping class labels to lists of SeqRecord objects.
    """
    sequences_by_class = defaultdict(list)
    for record in SeqIO.parse(input_fasta, "fasta"):
        sequence_class = record.description.split('|')[-1]
        sequences_by_class[sequence_class].append(record)
    return sequences_by_class

# %%
def align_sequences(mafft_path, input_fasta, output_fasta):
    """
    Perform multiple sequence alignment using MAFFT.

    Parameters:
    mafft_path (str): Absolute path to the MAFFT executable.
    input_fasta (str): Path to the input FASTA file containing unaligned sequences.
    output_fasta (str): Path to the output FASTA file to save aligned sequences.

    Notes:
    - Uses '--maxiterate' and '--thread' options for MAFFT to improve alignment.
    - Suppresses MAFFT output with '--quiet' for cleaner logs.
    """
    command = [
        mafft_path,
        '--maxiterate', '1000',
        '--thread', '20',
        '--quiet',
        input_fasta
    ]
    print(f"Executing command: {' '.join(command)}")

    with open(output_fasta, 'w') as outfile:
        try:
            subprocess.run(
                command,
                check=True,
                stdout=outfile,
                stderr=subprocess.PIPE,
                text=True
            )
            print(f"MAFFT successfully executed for {input_fasta}")
        except subprocess.CalledProcessError as e:
            print(f"Error executing MAFFT for {input_fasta}: {e.stderr}")

# %%
def read_alignment(aligned_fasta):
    """
    Read an aligned FASTA file and return a MultipleSeqAlignment object.

    Parameters:
    aligned_fasta (str): Path to the aligned FASTA file.

    Returns:
    MultipleSeqAlignment: An object containing aligned sequences.
    """
    return AlignIO.read(aligned_fasta, "fasta")

# %%
def generate_consensus(align):
    """
    Generate a consensus sequence from a multiple sequence alignment.

    Parameters:
    align (MultipleSeqAlignment): Alignment object containing aligned sequences.

    Returns:
    Seq: Consensus sequence as a Seq object.
    """
    summary_align = AlignInfo.SummaryInfo(align)
    consensus_seq = summary_align.gap_consensus(threshold=0.7, ambiguous='N')
    return consensus_seq

# %%
def generate_consensus_per_class(input_fasta, output_fasta, mafft_path):
    """
    Generate consensus sequences for each class in the input FASTA file.

    Parameters:
    input_fasta (str): Path to the input FASTA file containing sequences with class labels.
    output_fasta (str): Path to the output FASTA file to save consensus sequences.
    mafft_path (str): Absolute path to the MAFFT executable.

    Workflow:
    - Processes sequences grouped by class.
    - Performs multiple sequence alignment using MAFFT.
    - Generates a consensus sequence for each class.
    - Writes the consensus sequences to the output FASTA file.
    """
    sequences_by_class = process_sequences_by_class(input_fasta)
    consensus_records = []

    for cls, records in sequences_by_class.items():
        temp_fasta = f'temp_{cls}.fasta'
        aligned_fasta = f'{cls}_aligned.fasta'
        
        if not os.path.exists(aligned_fasta):
            write_temp_fasta(records, temp_fasta)
            align_sequences(mafft_path, temp_fasta, aligned_fasta)
            if os.path.exists(temp_fasta):
                os.remove(temp_fasta)

        if os.path.exists(aligned_fasta):
            align = read_alignment(aligned_fasta)
            os.remove(aligned_fasta)
        else:
            print(f"Failed to generate alignment for class {cls}")
            continue

        consensus_seq = generate_consensus(align)
        consensus_records.append(SeqRecord(consensus_seq, id=cls, description=""))

    SeqIO.write(consensus_records, output_fasta, "fasta")

# %%
# List of input and output file paths
files = [
    ('../data/Human_betaherpesvirus_5/US28/US28_nucleotide_sequences.fasta',
     '../data/Human_betaherpesvirus_5/US28/US28_consensus.fasta'),
    ('../data/Human_betaherpesvirus_5/UL55/UL55_nucleotide_sequences.fasta',
     '../data/Human_betaherpesvirus_5/UL55/UL55_consensus.fasta'),
    ('../data/Human_betaherpesvirus_5/UL73/UL73_nucleotide_sequences.fasta',
     '../data/Human_betaherpesvirus_5/UL73/UL73_consensus.fasta'),
    ('../data/Severe_acute_respiratory_syndrome_coronavirus_2/Severe_acute_respiratory_syndrome_coronavirus_2_nucleotide_sequences.fasta',
     '../data/Severe_acute_respiratory_syndrome_coronavirus_2/Severe_acute_respiratory_syndrome_coronavirus_2_consensus.fasta'),
    ('../data/Human_immunodeficiency_virus_1/Human_immunodeficiency_virus_1_nucleotide_sequences.fasta',
     '../data/Human_immunodeficiency_virus_1/Human_immunodeficiency_virus_1_consensus.fasta')
]

# Absolute path to the MAFFT executable
mafft_path = os.path.abspath("../lib/mafft/mafft.bat")

# Check if MAFFT executable exists before proceeding
if not os.path.exists(mafft_path):
    print(f"MAFFT executable not found at {mafft_path}")
else:
    # Process each pair of input and output files
    for input_fasta, output_fasta in files:
        print(f"Processing {output_fasta}")
        generate_consensus_per_class(input_fasta, output_fasta, mafft_path)
# Out:
# Processing ../data/Human_betaherpesvirus_5/US28/US28_consensus.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_A1.fasta
# MAFFT successfully executed for temp_A1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_A2.fasta
# MAFFT successfully executed for temp_A2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_D.fasta
# MAFFT successfully executed for temp_D.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B2.fasta
# MAFFT successfully executed for temp_B2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B1.fasta
# MAFFT successfully executed for temp_B1.fasta
# Processing ../data/Human_betaherpesvirus_5/UL55/UL55_consensus.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_1.fasta
# MAFFT successfully executed for temp_1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_2.fasta
# MAFFT successfully executed for temp_2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_4.fasta
# MAFFT successfully executed for temp_4.fasta
# Processing ../data/Human_betaherpesvirus_5/UL73/UL73_consensus.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_4b.fasta
# MAFFT successfully executed for temp_4b.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_4c.fasta
# MAFFT successfully executed for temp_4c.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_1.fasta
# MAFFT successfully executed for temp_1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_4a.fasta
# MAFFT successfully executed for temp_4a.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_3b.fasta
# MAFFT successfully executed for temp_3b.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_3a.fasta
# MAFFT successfully executed for temp_3a.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_2.fasta
# MAFFT successfully executed for temp_2.fasta
# Processing ../data/Severe_acute_respiratory_syndrome_coronavirus_2/Severe_acute_respiratory_syndrome_coronavirus_2_consensus.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.1.7.fasta
# MAFFT successfully executed for temp_B.1.1.7.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_JN.1.fasta
# MAFFT successfully executed for temp_JN.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_JN.1.11.1.fasta
# MAFFT successfully executed for temp_JN.1.11.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.1.fasta
# MAFFT successfully executed for temp_BA.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.2.12.1.fasta
# MAFFT successfully executed for temp_BA.2.12.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.2.fasta
# MAFFT successfully executed for temp_B.1.2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.2.fasta
# MAFFT successfully executed for temp_BA.2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.2.86.1.fasta
# MAFFT successfully executed for temp_BA.2.86.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_XBB.2.3.fasta
# MAFFT successfully executed for temp_XBB.2.3.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_XBB.fasta
# MAFFT successfully executed for temp_XBB.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.1.fasta
# MAFFT successfully executed for temp_B.1.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_CH.1.1.fasta
# MAFFT successfully executed for temp_CH.1.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_XBB.1.5.fasta
# MAFFT successfully executed for temp_XBB.1.5.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.fasta
# MAFFT successfully executed for temp_B.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_EG.5.1.fasta
# MAFFT successfully executed for temp_EG.5.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.617.2.fasta
# MAFFT successfully executed for temp_B.1.617.2.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.526.fasta
# MAFFT successfully executed for temp_B.1.526.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.429.fasta
# MAFFT successfully executed for temp_B.1.429.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.4.fasta
# MAFFT successfully executed for temp_BA.4.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BQ.1.fasta
# MAFFT successfully executed for temp_BQ.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_C.37.fasta
# MAFFT successfully executed for temp_C.37.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_P.1.fasta
# MAFFT successfully executed for temp_P.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.621.fasta
# MAFFT successfully executed for temp_B.1.621.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.427.fasta
# MAFFT successfully executed for temp_B.1.427.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.177.fasta
# MAFFT successfully executed for temp_B.1.177.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.525.fasta
# MAFFT successfully executed for temp_B.1.525.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.351.fasta
# MAFFT successfully executed for temp_B.1.351.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.5.fasta
# MAFFT successfully executed for temp_BA.5.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.1.1.fasta
# MAFFT successfully executed for temp_B.1.1.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.617.1.fasta
# MAFFT successfully executed for temp_B.1.617.1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.1.1.529.fasta
# MAFFT successfully executed for temp_B.1.1.529.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_XBB.1.16.fasta
# MAFFT successfully executed for temp_XBB.1.16.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_BA.2.75.fasta
# MAFFT successfully executed for temp_BA.2.75.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_D.2.fasta
# MAFFT successfully executed for temp_D.2.fasta
# Processing ../data/Human_immunodeficiency_virus_1/Human_immunodeficiency_virus_1_consensus.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_02_AG.fasta
# MAFFT successfully executed for temp_02_AG.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_A1.fasta
# MAFFT successfully executed for temp_A1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_01_AE.fasta
# MAFFT successfully executed for temp_01_AE.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_B.fasta
# MAFFT successfully executed for temp_B.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_G.fasta
# MAFFT successfully executed for temp_G.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_C.fasta
# MAFFT successfully executed for temp_C.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_D.fasta
# MAFFT successfully executed for temp_D.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_F1.fasta
# MAFFT successfully executed for temp_F1.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_O.fasta
# MAFFT successfully executed for temp_O.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_35_A1D.fasta
# MAFFT successfully executed for temp_35_A1D.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_08_BC.fasta
# MAFFT successfully executed for temp_08_BC.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_A6.fasta
# MAFFT successfully executed for temp_A6.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_11_cpx.fasta
# MAFFT successfully executed for temp_11_cpx.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_20_BG.fasta
# MAFFT successfully executed for temp_20_BG.fasta
# Executing command: c:\Users\lebat\Documents\KSS\lib\mafft\mafft.bat --maxiterate 1000 --thread 20 --quiet temp_63_02A6.fasta
# MAFFT successfully executed for temp_63_02A6.fasta
