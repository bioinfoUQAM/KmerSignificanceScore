# %%
import sys
import json
import ast
import os
sys.path.append('../utils')
import utils

# %%
def calculate_variation_presence(data, input_position, input_kmer):
    """
    Calculate the percentage presence of a specific k-mer variation at a given position across different classes.

    Parameters:
    - data (dict): The data containing sequences and their associated classes.
    - input_position (tuple or str): The position to check. If a string, it will be converted to a tuple.
    - input_kmer (str): The k-mer variation to look for.

    Returns:
    - variation_percentages (dict): A dictionary with class IDs as keys and percentage presence as values.
    """
    # If input_position is a string, convert it to a tuple safely
    if isinstance(input_position, str):
        input_position = ast.literal_eval(input_position)
    
    class_counts = {}
    class_variation_counts = {}

    # Count occurrences and prepare data
    for gene_sequences in data.values():
        for seq_id, positions in gene_sequences.items():
            class_id = seq_id.split('|')[-1]
            class_counts.setdefault(class_id, {})
            class_variation_counts.setdefault(class_id, {})

            # Initialize counts if not present
            class_counts[class_id].setdefault(input_position, 0)
            class_variation_counts[class_id].setdefault(input_position, 0)

            # Convert keys to tuples for comparison
            for key_str, pos_data in positions.items():
                key_tuple = ast.literal_eval(key_str)

                # Check for matching position
                if input_position == key_tuple:
                    class_counts[class_id][input_position] += 1

                    # Check for matching k-mer variation
                    if pos_data['variations'] == input_kmer:
                        class_variation_counts[class_id][input_position] += 1

    # Calculate percentages
    variation_percentages = {}
    for class_id in class_counts:
        count = class_variation_counts[class_id][input_position]
        total = class_counts[class_id][input_position]
        percentage = (count / total) * 100 if total > 0 else 0
        variation_percentages[class_id] = percentage

    return variation_percentages

# %%
def get_top_n_scores(file_paths, score_index, top_n):
    """
    Retrieve the top N scores from given JSON files based on a specified score index.

    Parameters:
    - file_paths (list): List of paths to JSON files containing scores.
    - score_index (int): The index of the score to sort by in the scores list.
    - top_n (int): The number of top scores to retrieve.

    Returns:
    - list: A list of tuples containing (file_path, key, score) of the top N scores.
    """
    all_scores = []

    # Loop through each file and collect scores
    for json_file_path in file_paths:
        try:
            scores = utils.load_data_from_json(json_file_path)
            # Collect score tuples
            score_tuples = [
                (json_file_path, key, values[score_index])
                for key, values in scores.items()
                if isinstance(values, list) and len(values) > score_index
            ]
            all_scores.extend(score_tuples)
        except Exception as e:
            print(f"Error processing file {json_file_path}: {str(e)}")

    # Sort and retrieve top N scores
    sorted_scores = sorted(all_scores, key=lambda x: x[2], reverse=True)
    return sorted_scores[:top_n]

# %%
def process_dataset(name, score_index, n):
    """
    Process a single dataset to extract top N k-mer variations and their percentages.

    Parameters:
    - name (str): The name of the dataset.
    - score_index (int): The index of the score to sort by.
    - n (int): The number of top scores to retrieve.
    """
    print(f"\nProcessing: {name}")

    # Determine file paths and genes based on dataset name
    if name == "Human_immunodeficiency_virus_1":
        genes = ['gag-pol', 'gag', 'env']
        base_path = f"../data/{name}/results"
        compiled_results_path = os.path.join(base_path, f"{name}_compiled_results.json")
        data_path = os.path.join(base_path, f"{name}_results.json")
    elif name == "Severe_acute_respiratory_syndrome_coronavirus_2":
        genes = ['ORF1a', 'ORF1b', 'S', 'N', 'M', 'E']
        base_path = f"../data/{name}/results"
        compiled_results_path = os.path.join(base_path, f"{name}_compiled_results.json")
        data_path = os.path.join(base_path, f"{name}_results.json")
    else:
        genes = [name]
        base_path = f"../data/Human_betaherpesvirus_5/{name}/results"
        compiled_results_path = os.path.join(base_path, f"{name}_compiled_results.json")
        data_path = os.path.join(base_path, f"{name}_results.json")

    # Prepare file paths for score files
    file_paths = [os.path.join(base_path, f"{gene}_uncategorized_scores.json") for gene in genes]

    # Get top N scores
    top_n_scores = get_top_n_scores(file_paths, score_index, n)

    # Extract positions and associated genes
    positions = []
    for file_path, key, _ in top_n_scores:
        position_part = key.split(',', 1)[0][1:]  # Extract position
        gene = os.path.basename(file_path).split('_')[0]
        positions.append((position_part, gene, key))
    
    if name == "UL55": 
        positions.extend([('82', 'UL55', "(82, 'ACTCGTGGA')"), 
                          ('100', 'UL55', "(100, 'ACTCACAGT')"), 
                          ('145', 'UL55', "(145, 'CGATCCGGT')")])

    # Load compiled results and data once
    with open(compiled_results_path, 'r') as file:
        compiled_data = json.load(file)
    data = utils.load_data_from_json(data_path)

    # Collect k-mers and their variations
    k_mers_variations_dict = {}
    for position, gene, key_in_scores in positions:
        # Retrieve variations for the position
        gene_data = compiled_data.get(gene, {})
        for key, value in gene_data.items():
            current_position = key.split(',', 1)[0][1:]
            if current_position == position:
                k_mers_variations_dict[(key, gene)] = [value['variations'], value['amino_acid_changes']]

    # Print the results
    for (key, gene), variations in k_mers_variations_dict.items():
        for kmer in variations[0]:
            print(f"K-mer variations: {variations[0]}, Key: {key}, K-mer: {kmer}, Gene: {gene}")
            variation_percentages = calculate_variation_presence(data, key, kmer)
            print(f"Percentages of {kmer} at key {key}:")
            for class_id, percentage in variation_percentages.items():
                if percentage != 0:
                    print(f"  Class {class_id}: {percentage:.2f}%")
            print()

# %%
# Usage example
datasets = [
    'US28',
    'UL55',
    'UL73',
    'Severe_acute_respiratory_syndrome_coronavirus_2',
    'Human_immunodeficiency_virus_1',
]
score_index = 3  # Index of the score to sort by
n = 5  # Number of top scores to retrieve

for dataset_name in datasets:
    process_dataset(dataset_name, score_index, n)
# Out:
# Processing: US28
# K-mer variations: ['GACGCGGCT', 'GCCGCGACT', 'GAAGCGACT', 'GGAGCAACC', 'GACGCGACT'], Key: (55, 'GACGCGACT'), K-mer: GACGCGGCT, Gene: US28
# Percentages of GACGCGGCT at key (55, 'GACGCGACT'):
#   Class C: 100.00%
#
# K-mer variations: ['GACGCGGCT', 'GCCGCGACT', 'GAAGCGACT', 'GGAGCAACC', 'GACGCGACT'], Key: (55, 'GACGCGACT'), K-mer: GCCGCGACT, Gene: US28
# Percentages of GCCGCGACT at key (55, 'GACGCGACT'):
#   Class A1: 100.00%
#
# K-mer variations: ['GACGCGGCT', 'GCCGCGACT', 'GAAGCGACT', 'GGAGCAACC', 'GACGCGACT'], Key: (55, 'GACGCGACT'), K-mer: GAAGCGACT, Gene: US28
# Percentages of GAAGCGACT at key (55, 'GACGCGACT'):
#   Class D: 100.00%
#
# K-mer variations: ['GACGCGGCT', 'GCCGCGACT', 'GAAGCGACT', 'GGAGCAACC', 'GACGCGACT'], Key: (55, 'GACGCGACT'), K-mer: GGAGCAACC, Gene: US28
# Percentages of GGAGCAACC at key (55, 'GACGCGACT'):
#   Class B2: 100.00%
#   Class B1: 100.00%
#
# K-mer variations: ['GACGCGGCT', 'GCCGCGACT', 'GAAGCGACT', 'GGAGCAACC', 'GACGCGACT'], Key: (55, 'GACGCGACT'), K-mer: GACGCGACT, Gene: US28
# Percentages of GACGCGACT at key (55, 'GACGCGACT'):
#   Class A2: 99.24%
#
# K-mer variations: ['CCTTGTACC', 'CCCTGTGTT', 'CCTTGTGTT', 'CCCTGTGTC'], Key: (64, 'CCTTGTGTT'), K-mer: CCTTGTACC, Gene: US28
# Percentages of CCTTGTACC at key (64, 'CCTTGTGTT'):
#   Class B2: 100.00%
#   Class B1: 100.00%
#
# K-mer variations: ['CCTTGTACC', 'CCCTGTGTT', 'CCTTGTGTT', 'CCCTGTGTC'], Key: (64, 'CCTTGTGTT'), K-mer: CCCTGTGTT, Gene: US28
# Percentages of CCCTGTGTT at key (64, 'CCTTGTGTT'):
#   Class C: 100.00%
#
# K-mer variations: ['CCTTGTACC', 'CCCTGTGTT', 'CCTTGTGTT', 'CCCTGTGTC'], Key: (64, 'CCTTGTGTT'), K-mer: CCTTGTGTT, Gene: US28
# Percentages of CCTTGTGTT at key (64, 'CCTTGTGTT'):
#   Class A1: 100.00%
#   Class A2: 98.47%
#
# K-mer variations: ['CCTTGTACC', 'CCCTGTGTT', 'CCTTGTGTT', 'CCCTGTGTC'], Key: (64, 'CCTTGTGTT'), K-mer: CCCTGTGTC, Gene: US28
# Percentages of CCCTGTGTC at key (64, 'CCTTGTGTT'):
#   Class D: 100.00%
#
# K-mer variations: ['TACGACCTT', 'TACGACGAT', 'TACGATGAA', 'TATGATGAA'], Key: (46, 'TACGATGAA'), K-mer: TACGACCTT, Gene: US28
# Percentages of TACGACCTT at key (46, 'TACGATGAA'):
#   Class B2: 100.00%
#   Class B1: 100.00%
#
# K-mer variations: ['TACGACCTT', 'TACGACGAT', 'TACGATGAA', 'TATGATGAA'], Key: (46, 'TACGATGAA'), K-mer: TACGACGAT, Gene: US28
# Percentages of TACGACGAT at key (46, 'TACGATGAA'):
#   Class D: 100.00%
#
# K-mer variations: ['TACGACCTT', 'TACGACGAT', 'TACGATGAA', 'TATGATGAA'], Key: (46, 'TACGATGAA'), K-mer: TACGATGAA, Gene: US28
# Percentages of TACGATGAA at key (46, 'TACGATGAA'):
#   Class A1: 99.37%
#   Class C: 6.06%
#   Class A2: 100.00%
#
# K-mer variations: ['TACGACCTT', 'TACGACGAT', 'TACGATGAA', 'TATGATGAA'], Key: (46, 'TACGATGAA'), K-mer: TATGATGAA, Gene: US28
# Percentages of TATGATGAA at key (46, 'TACGATGAA'):
#   Class C: 93.94%
#
# K-mer variations: ['CTAACTGAC', 'TTCACCGAC', 'CTCACCGAC'], Key: (73, 'TTCACCGAC'), K-mer: CTAACTGAC, Gene: US28
# Percentages of CTAACTGAC at key (73, 'TTCACCGAC'):
#   Class C: 100.00%
#
# K-mer variations: ['CTAACTGAC', 'TTCACCGAC', 'CTCACCGAC'], Key: (73, 'TTCACCGAC'), K-mer: TTCACCGAC, Gene: US28
# Percentages of TTCACCGAC at key (73, 'TTCACCGAC'):
#   Class A1: 77.36%
#   Class A2: 100.00%
#   Class B2: 100.00%
#   Class B1: 100.00%
#
# K-mer variations: ['CTAACTGAC', 'TTCACCGAC', 'CTCACCGAC'], Key: (73, 'TTCACCGAC'), K-mer: CTCACCGAC, Gene: US28
# Percentages of CTCACCGAC at key (73, 'TTCACCGAC'):
#   Class D: 100.00%
#
# K-mer variations: ['CCGGTTACG', 'CCGGTCACG', 'CCAGTCACG', 'CCAGTTACG'], Key: (100, 'CCAGTTACG'), K-mer: CCGGTTACG, Gene: US28
# Percentages of CCGGTTACG at key (100, 'CCAGTTACG'):
#   Class A1: 90.57%
#
# K-mer variations: ['CCGGTTACG', 'CCGGTCACG', 'CCAGTCACG', 'CCAGTTACG'], Key: (100, 'CCAGTTACG'), K-mer: CCGGTCACG, Gene: US28
# Percentages of CCGGTCACG at key (100, 'CCAGTTACG'):
#   Class A1: 8.18%
#   Class A2: 1.53%
#   Class D: 6.52%
#   Class B2: 8.00%
#   Class B1: 100.00%
#
# K-mer variations: ['CCGGTTACG', 'CCGGTCACG', 'CCAGTCACG', 'CCAGTTACG'], Key: (100, 'CCAGTTACG'), K-mer: CCAGTCACG, Gene: US28
# Percentages of CCAGTCACG at key (100, 'CCAGTTACG'):
#   Class C: 69.70%
#   Class A2: 12.21%
#   Class D: 91.30%
#   Class B2: 64.00%
#
# K-mer variations: ['CCGGTTACG', 'CCGGTCACG', 'CCAGTCACG', 'CCAGTTACG'], Key: (100, 'CCAGTTACG'), K-mer: CCAGTTACG, Gene: US28
# Percentages of CCAGTTACG at key (100, 'CCAGTTACG'):
#   Class A1: 0.63%
#   Class C: 30.30%
#   Class A2: 86.26%
#   Class D: 2.17%
#   Class B2: 28.00%
#
#
# Processing: UL55
# K-mer variations: ['AGGACCAGA', 'AGAACCAAA', 'AGAACCAGA', 'AGAACCAAG'], Key: (1369, 'AGAACCAAA'), K-mer: AGGACCAGA, Gene: UL55
# Percentages of AGGACCAGA at key (1369, 'AGAACCAAA'):
#   Class 2: 100.00%
#
# K-mer variations: ['AGGACCAGA', 'AGAACCAAA', 'AGAACCAGA', 'AGAACCAAG'], Key: (1369, 'AGAACCAAA'), K-mer: AGAACCAAA, Gene: UL55
# Percentages of AGAACCAAA at key (1369, 'AGAACCAAA'):
#   Class 1: 99.47%
#
# K-mer variations: ['AGGACCAGA', 'AGAACCAAA', 'AGAACCAGA', 'AGAACCAAG'], Key: (1369, 'AGAACCAAA'), K-mer: AGAACCAGA, Gene: UL55
# Percentages of AGAACCAGA at key (1369, 'AGAACCAAA'):
#   Class 4: 100.00%
#
# K-mer variations: ['AGGACCAGA', 'AGAACCAAA', 'AGAACCAGA', 'AGAACCAAG'], Key: (1369, 'AGAACCAAA'), K-mer: AGAACCAAG, Gene: UL55
# Percentages of AGAACCAAG at key (1369, 'AGAACCAAA'):
#   Class 3: 100.00%
#
# K-mer variations: ['TCCGACCCC', 'TCCGATTCC', 'TCCGACTCC', 'TCCGACTCT'], Key: (1153, 'TCCGACTCT'), K-mer: TCCGACCCC, Gene: UL55
# Percentages of TCCGACCCC at key (1153, 'TCCGACTCT'):
#   Class 3: 92.00%
#
# K-mer variations: ['TCCGACCCC', 'TCCGATTCC', 'TCCGACTCC', 'TCCGACTCT'], Key: (1153, 'TCCGACTCT'), K-mer: TCCGATTCC, Gene: UL55
# Percentages of TCCGATTCC at key (1153, 'TCCGACTCT'):
#   Class 4: 96.97%
#
# K-mer variations: ['TCCGACCCC', 'TCCGATTCC', 'TCCGACTCC', 'TCCGACTCT'], Key: (1153, 'TCCGACTCT'), K-mer: TCCGACTCC, Gene: UL55
# Percentages of TCCGACTCC at key (1153, 'TCCGACTCT'):
#   Class 2: 100.00%
#
# K-mer variations: ['TCCGACCCC', 'TCCGATTCC', 'TCCGACTCC', 'TCCGACTCT'], Key: (1153, 'TCCGACTCT'), K-mer: TCCGACTCT, Gene: UL55
# Percentages of TCCGACTCT at key (1153, 'TCCGACTCT'):
#   Class 1: 100.00%
#   Class 4: 3.03%
#
# K-mer variations: ['ACCGGCGGA', 'AGCGGCGGT', 'ACTGGTGGT', 'ACAGGCGGT'], Key: (1270, 'ACTGGTGGT'), K-mer: ACCGGCGGA, Gene: UL55
# Percentages of ACCGGCGGA at key (1270, 'ACTGGTGGT'):
#   Class 4: 96.97%
#
# K-mer variations: ['ACCGGCGGA', 'AGCGGCGGT', 'ACTGGTGGT', 'ACAGGCGGT'], Key: (1270, 'ACTGGTGGT'), K-mer: AGCGGCGGT, Gene: UL55
# Percentages of AGCGGCGGT at key (1270, 'ACTGGTGGT'):
#   Class 2: 100.00%
#
# K-mer variations: ['ACCGGCGGA', 'AGCGGCGGT', 'ACTGGTGGT', 'ACAGGCGGT'], Key: (1270, 'ACTGGTGGT'), K-mer: ACTGGTGGT, Gene: UL55
# Percentages of ACTGGTGGT at key (1270, 'ACTGGTGGT'):
#   Class 1: 100.00%
#   Class 4: 3.03%
#
# K-mer variations: ['ACCGGCGGA', 'AGCGGCGGT', 'ACTGGTGGT', 'ACAGGCGGT'], Key: (1270, 'ACTGGTGGT'), K-mer: ACAGGCGGT, Gene: UL55
# Percentages of ACAGGCGGT at key (1270, 'ACTGGTGGT'):
#   Class 3: 100.00%
#
# K-mer variations: ['AATGTAACT', 'AATACAACT', 'AATGCAACT', 'ACGACCACC'], Key: (1396, 'AATGCAACT'), K-mer: AATGTAACT, Gene: UL55
# Percentages of AATGTAACT at key (1396, 'AATGCAACT'):
#   Class 4: 100.00%
#
# K-mer variations: ['AATGTAACT', 'AATACAACT', 'AATGCAACT', 'ACGACCACC'], Key: (1396, 'AATGCAACT'), K-mer: AATACAACT, Gene: UL55
# Percentages of AATACAACT at key (1396, 'AATGCAACT'):
#   Class 2: 100.00%
#
# K-mer variations: ['AATGTAACT', 'AATACAACT', 'AATGCAACT', 'ACGACCACC'], Key: (1396, 'AATGCAACT'), K-mer: AATGCAACT, Gene: UL55
# Percentages of AATGCAACT at key (1396, 'AATGCAACT'):
#   Class 1: 100.00%
#
# K-mer variations: ['AATGTAACT', 'AATACAACT', 'AATGCAACT', 'ACGACCACC'], Key: (1396, 'AATGCAACT'), K-mer: ACGACCACC, Gene: UL55
# Percentages of ACGACCACC at key (1396, 'AATGCAACT'):
#   Class 3: 98.67%
#
# K-mer variations: ['ACG---CGT', 'ACTCATAAT', 'ACTCATAGT', 'ACTCAT---'], Key: (1360, 'ACTCATAAT'), K-mer: ACG---CGT, Gene: UL55
# Percentages of ACG---CGT at key (1360, 'ACTCATAAT'):
#   Class 3: 100.00%
#
# K-mer variations: ['ACG---CGT', 'ACTCATAAT', 'ACTCATAGT', 'ACTCAT---'], Key: (1360, 'ACTCATAAT'), K-mer: ACTCATAAT, Gene: UL55
# Percentages of ACTCATAAT at key (1360, 'ACTCATAAT'):
#   Class 1: 100.00%
#
# K-mer variations: ['ACG---CGT', 'ACTCATAAT', 'ACTCATAGT', 'ACTCAT---'], Key: (1360, 'ACTCATAAT'), K-mer: ACTCATAGT, Gene: UL55
# Percentages of ACTCATAGT at key (1360, 'ACTCATAAT'):
#   Class 4: 100.00%
#
# K-mer variations: ['ACG---CGT', 'ACTCATAAT', 'ACTCATAGT', 'ACTCAT---'], Key: (1360, 'ACTCATAAT'), K-mer: ACTCAT---, Gene: UL55
# Percentages of ACTCAT--- at key (1360, 'ACTCATAAT'):
#   Class 2: 98.55%
#
# K-mer variations: ['ACTCGTGGA', 'ACTTCTCATGCA', 'ACTTCCCATGCA', 'TCTCGTGCA'], Key: (82, 'ACTCGTGGA'), K-mer: ACTCGTGGA, Gene: UL55
# Percentages of ACTCGTGGA at key (82, 'ACTCGTGGA'):
#   Class 1: 94.21%
#   Class 2: 1.45%
#   Class 3: 5.33%
#
# K-mer variations: ['ACTCGTGGA', 'ACTTCTCATGCA', 'ACTTCCCATGCA', 'TCTCGTGCA'], Key: (82, 'ACTCGTGGA'), K-mer: ACTTCTCATGCA, Gene: UL55
# Percentages of ACTTCTCATGCA at key (82, 'ACTCGTGGA'):
#   Class 1: 2.11%
#   Class 2: 1.45%
#   Class 3: 81.33%
#
# K-mer variations: ['ACTCGTGGA', 'ACTTCTCATGCA', 'ACTTCCCATGCA', 'TCTCGTGCA'], Key: (82, 'ACTCGTGGA'), K-mer: ACTTCCCATGCA, Gene: UL55
# Percentages of ACTTCCCATGCA at key (82, 'ACTCGTGGA'):
#   Class 2: 79.71%
#   Class 3: 10.67%
#
# K-mer variations: ['ACTCGTGGA', 'ACTTCTCATGCA', 'ACTTCCCATGCA', 'TCTCGTGCA'], Key: (82, 'ACTCGTGGA'), K-mer: TCTCGTGCA, Gene: UL55
# Percentages of TCTCGTGCA at key (82, 'ACTCGTGGA'):
#   Class 1: 1.05%
#   Class 4: 100.00%
#
# K-mer variations: ['ACCCACAAT', 'ACTCACAAT', 'CATAATGGA', 'GCTCACAAT', 'ACTCACAGT'], Key: (100, 'ACTCACAGT'), K-mer: ACCCACAAT, Gene: UL55
# Percentages of ACCCACAAT at key (100, 'ACTCACAGT'):
#   Class 2: 52.17%
#
# K-mer variations: ['ACCCACAAT', 'ACTCACAAT', 'CATAATGGA', 'GCTCACAAT', 'ACTCACAGT'], Key: (100, 'ACTCACAGT'), K-mer: ACTCACAAT, Gene: UL55
# Percentages of ACTCACAAT at key (100, 'ACTCACAGT'):
#   Class 1: 4.21%
#   Class 2: 34.78%
#   Class 3: 18.67%
#
# K-mer variations: ['ACCCACAAT', 'ACTCACAAT', 'CATAATGGA', 'GCTCACAAT', 'ACTCACAGT'], Key: (100, 'ACTCACAGT'), K-mer: CATAATGGA, Gene: UL55
# Percentages of CATAATGGA at key (100, 'ACTCACAGT'):
#   Class 1: 1.58%
#   Class 4: 93.94%
#
# K-mer variations: ['ACCCACAAT', 'ACTCACAAT', 'CATAATGGA', 'GCTCACAAT', 'ACTCACAGT'], Key: (100, 'ACTCACAGT'), K-mer: GCTCACAAT, Gene: UL55
# Percentages of GCTCACAAT at key (100, 'ACTCACAGT'):
#   Class 3: 78.67%
#
# K-mer variations: ['ACCCACAAT', 'ACTCACAAT', 'CATAATGGA', 'GCTCACAAT', 'ACTCACAGT'], Key: (100, 'ACTCACAGT'), K-mer: ACTCACAGT, Gene: UL55
# Percentages of ACTCACAGT at key (100, 'ACTCACAGT'):
#   Class 1: 94.21%
#   Class 2: 13.04%
#   Class 3: 2.67%
#   Class 4: 3.03%
#
# K-mer variations: ['CGGTCAATC', 'CGATCCGGT', 'CGGTCAGTT', 'CGGTCAGTC', 'CGGTCA---'], Key: (145, 'CGATCCGGT'), K-mer: CGGTCAATC, Gene: UL55
# Percentages of CGGTCAATC at key (145, 'CGATCCGGT'):
#   Class 1: 1.05%
#   Class 4: 96.97%
#
# K-mer variations: ['CGGTCAATC', 'CGATCCGGT', 'CGGTCAGTT', 'CGGTCAGTC', 'CGGTCA---'], Key: (145, 'CGATCCGGT'), K-mer: CGATCCGGT, Gene: UL55
# Percentages of CGATCCGGT at key (145, 'CGATCCGGT'):
#   Class 1: 92.63%
#   Class 4: 3.03%
#
# K-mer variations: ['CGGTCAATC', 'CGATCCGGT', 'CGGTCAGTT', 'CGGTCAGTC', 'CGGTCA---'], Key: (145, 'CGATCCGGT'), K-mer: CGGTCAGTT, Gene: UL55
# Percentages of CGGTCAGTT at key (145, 'CGATCCGGT'):
#   Class 1: 2.11%
#   Class 3: 82.67%
#
# K-mer variations: ['CGGTCAATC', 'CGATCCGGT', 'CGGTCAGTT', 'CGGTCAGTC', 'CGGTCA---'], Key: (145, 'CGATCCGGT'), K-mer: CGGTCAGTC, Gene: UL55
# Percentages of CGGTCAGTC at key (145, 'CGATCCGGT'):
#   Class 1: 2.11%
#   Class 2: 52.17%
#   Class 3: 14.67%
#
# K-mer variations: ['CGGTCAATC', 'CGATCCGGT', 'CGGTCAGTT', 'CGGTCAGTC', 'CGGTCA---'], Key: (145, 'CGATCCGGT'), K-mer: CGGTCA---, Gene: UL55
# Percentages of CGGTCA--- at key (145, 'CGATCCGGT'):
#   Class 2: 34.78%
#
#
# Processing: UL73
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: ACTAGCGTA, Gene: UL73
# Percentages of ACTAGCGTA at key (109, 'GCTAGCGTA'):
#   Class 1: 26.47%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: CACGCCTCA, Gene: UL73
# Percentages of CACGCCTCA at key (109, 'GCTAGCGTA'):
#   Class 4b: 1.75%
#   Class 4c: 96.63%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: TCTAGCGTG, Gene: UL73
# Percentages of TCTAGCGTG at key (109, 'GCTAGCGTA'):
#   Class 3a: 100.00%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: TCTAGTGTA, Gene: UL73
# Percentages of TCTAGTGTA at key (109, 'GCTAGCGTA'):
#   Class 3b: 100.00%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: TCTAGTGTG, Gene: UL73
# Percentages of TCTAGTGTG at key (109, 'GCTAGCGTA'):
#   Class 2: 100.00%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: CGCACCTTA, Gene: UL73
# Percentages of CGCACCTTA at key (109, 'GCTAGCGTA'):
#   Class 4a: 100.00%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: CACACCTCA, Gene: UL73
# Percentages of CACACCTCA at key (109, 'GCTAGCGTA'):
#   Class 4b: 98.25%
#
# K-mer variations: ['ACTAGCGTA', 'CACGCCTCA', 'TCTAGCGTG', 'TCTAGTGTA', 'TCTAGTGTG', 'CGCACCTTA', 'CACACCTCA', 'GCTAGCGTA'], Key: (109, 'GCTAGCGTA'), K-mer: GCTAGCGTA, Gene: UL73
# Percentages of GCTAGCGTA at key (109, 'GCTAGCGTA'):
#   Class 1: 73.53%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGACAACT, Gene: UL73
# Percentages of ACGACAACT at key (163, 'ACGACGACT'):
#   Class 2: 74.42%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGGCGACA, Gene: UL73
# Percentages of ACGGCGACA at key (163, 'ACGACGACT'):
#   Class 4b: 1.75%
#   Class 4c: 96.63%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGACGACC, Gene: UL73
# Percentages of ACGACGACC at key (163, 'ACGACGACT'):
#   Class 3b: 100.00%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGACGACT, Gene: UL73
# Percentages of ACGACGACT at key (163, 'ACGACGACT'):
#   Class 1: 100.00%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGATGAGT, Gene: UL73
# Percentages of ACGATGAGT at key (163, 'ACGACGACT'):
#   Class 3a: 98.88%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: ACGAGGAGC, Gene: UL73
# Percentages of ACGAGGAGC at key (163, 'ACGACGACT'):
#   Class 4a: 99.00%
#
# K-mer variations: ['ACGACAACT', 'ACGGCGACA', 'ACGACGACC', 'ACGACGACT', 'ACGATGAGT', 'ACGAGGAGC', 'GTGACAAGT'], Key: (163, 'ACGACGACT'), K-mer: GTGACAAGT, Gene: UL73
# Percentages of GTGACAAGT at key (163, 'ACGACGACT'):
#   Class 4b: 96.49%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GCGGCG---, Gene: UL73
# Percentages of GCGGCG--- at key (46, 'GTGGCAGAG'):
#   Class 4b: 15.79%
#   Class 4a: 100.00%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GCGGCA---, Gene: UL73
# Percentages of GCGGCA--- at key (46, 'GTGGCAGAG'):
#   Class 4b: 84.21%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GCGGCAGGG, Gene: UL73
# Percentages of GCGGCAGGG at key (46, 'GTGGCAGAG'):
#   Class 3b: 70.45%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GCAGCGGGG, Gene: UL73
# Percentages of GCAGCGGGG at key (46, 'GTGGCAGAG'):
#   Class 3a: 98.88%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GTGGCAGAG, Gene: UL73
# Percentages of GTGGCAGAG at key (46, 'GTGGCAGAG'):
#   Class 1: 100.00%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GTGGCA---, Gene: UL73
# Percentages of GTGGCA--- at key (46, 'GTGGCAGAG'):
#   Class 4c: 100.00%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GCGGTAGGG, Gene: UL73
# Percentages of GCGGTAGGG at key (46, 'GTGGCAGAG'):
#   Class 3b: 29.55%
#
# K-mer variations: ['GCGGCG---', 'GCGGCA---', 'GCGGCAGGG', 'GCAGCGGGG', 'GTGGCAGAG', 'GTGGCA---', 'GCGGTAGGG', 'GTAACAGGG'], Key: (46, 'GTGGCAGAG'), K-mer: GTAACAGGG, Gene: UL73
# Percentages of GTAACAGGG at key (46, 'GTGGCAGAG'):
#   Class 2: 100.00%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: AGTTCTACT, Gene: UL73
# Percentages of AGTTCTACT at key (100, 'AAGTCTTCT'):
#   Class 4b: 1.75%
#   Class 4c: 97.75%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: CCAAGTCCT, Gene: UL73
# Percentages of CCAAGTCCT at key (100, 'AAGTCTTCT'):
#   Class 2: 100.00%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: AGCTCTACT, Gene: UL73
# Percentages of AGCTCTACT at key (100, 'AAGTCTTCT'):
#   Class 4b: 96.49%
#   Class 4c: 1.12%
#   Class 4a: 100.00%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: CCTCCTAGT, Gene: UL73
# Percentages of CCTCCTAGT at key (100, 'AAGTCTTCT'):
#   Class 3b: 100.00%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: AAATCGTCCAGT, Gene: UL73
# Percentages of AAATCGTCCAGT at key (100, 'AAGTCTTCT'):
#   Class 3a: 100.00%
#
# K-mer variations: ['AGTTCTACT', 'CCAAGTCCT', 'AGCTCTACT', 'CCTCCTAGT', 'AAATCGTCCAGT', 'AAGTCTTCT'], Key: (100, 'AAGTCTTCT'), K-mer: AAGTCTTCT, Gene: UL73
# Percentages of AAGTCTTCT at key (100, 'AAGTCTTCT'):
#   Class 1: 99.02%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACTGTTGCG, Gene: UL73
# Percentages of ACTGTTGCG at key (136, 'ACAGTTGCA'):
#   Class 4b: 1.75%
#   Class 4c: 98.88%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACAACTGCA, Gene: UL73
# Percentages of ACAACTGCA at key (136, 'ACAGTTGCA'):
#   Class 4a: 100.00%
#   Class 3a: 87.64%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACTACTGCG, Gene: UL73
# Percentages of ACTACTGCG at key (136, 'ACAGTTGCA'):
#   Class 4b: 98.25%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACGAGCGTA, Gene: UL73
# Percentages of ACGAGCGTA at key (136, 'ACAGTTGCA'):
#   Class 2: 100.00%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACAGTTGCA, Gene: UL73
# Percentages of ACAGTTGCA at key (136, 'ACAGTTGCA'):
#   Class 1: 100.00%
#
# K-mer variations: ['ACTGTTGCG', 'ACAACTGCA', 'ACTACTGCG', 'ACGAGCGTA', 'ACAGTTGCA', 'ACCAGCGTA'], Key: (136, 'ACAGTTGCA'), K-mer: ACCAGCGTA, Gene: UL73
# Percentages of ACCAGCGTA at key (136, 'ACAGTTGCA'):
#   Class 3b: 100.00%
#
#
# Processing: Severe_acute_respiratory_syndrome_coronavirus_2
# K-mer variations: ['CAGGATTTG', 'CAGGACTTG', 'CATGACTTG', 'CGGGACTTG'], Key: (154, 'CAGGACTTG'), K-mer: CAGGATTTG, Gene: S
# Percentages of CAGGATTTG at key (154, 'CAGGACTTG'):
#   Class B.1.1.7: 3.00%
#   Class BA.2.12.1: 93.00%
#   Class BA.2: 1.00%
#   Class BA.2.86.1: 1.00%
#   Class B.1.1: 1.00%
#   Class B.1.617.2: 1.00%
#   Class B.1.1.529: 2.00%
#
# K-mer variations: ['CAGGATTTG', 'CAGGACTTG', 'CATGACTTG', 'CGGGACTTG'], Key: (154, 'CAGGACTTG'), K-mer: CAGGACTTG, Gene: S
# Percentages of CAGGACTTG at key (154, 'CAGGACTTG'):
#   Class B.1.1.7: 97.00%
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.1: 100.00%
#   Class BA.2.12.1: 7.00%
#   Class B.1.2: 99.00%
#   Class BA.2: 98.00%
#   Class BA.2.86.1: 99.00%
#   Class XBB.2.3: 100.00%
#   Class XBB: 100.00%
#   Class B.1.1: 98.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 100.00%
#   Class B.1: 100.00%
#   Class B.1.617.2: 97.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 97.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 99.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 1.00%
#   Class B.1.351: 99.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 97.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['CAGGATTTG', 'CAGGACTTG', 'CATGACTTG', 'CGGGACTTG'], Key: (154, 'CAGGACTTG'), K-mer: CATGACTTG, Gene: S
# Percentages of CATGACTTG at key (154, 'CAGGACTTG'):
#   Class EG.5.1: 94.29%
#
# K-mer variations: ['CAGGATTTG', 'CAGGACTTG', 'CATGACTTG', 'CGGGACTTG'], Key: (154, 'CAGGACTTG'), K-mer: CGGGACTTG, Gene: S
# Percentages of CGGGACTTG at key (154, 'CAGGACTTG'):
#   Class B.1.525: 99.00%
#
# K-mer variations: ['AGATCGCTT', 'AGATTGTTT', 'AGATTGTTA', 'AGATCGTTT'], Key: (1360, 'AGATTGTTT'), K-mer: AGATCGCTT, Gene: S
# Percentages of AGATCGCTT at key (1360, 'AGATTGTTT'):
#   Class JN.1: 1.00%
#   Class JN.1.11.1: 98.00%
#
# K-mer variations: ['AGATCGCTT', 'AGATTGTTT', 'AGATTGTTA', 'AGATCGTTT'], Key: (1360, 'AGATTGTTT'), K-mer: AGATTGTTT, Gene: S
# Percentages of AGATTGTTT at key (1360, 'AGATTGTTT'):
#   Class B.1.1.7: 100.00%
#   Class BA.1: 100.00%
#   Class BA.2.12.1: 100.00%
#   Class B.1.2: 99.00%
#   Class BA.2: 100.00%
#   Class BA.2.86.1: 82.00%
#   Class XBB.2.3: 99.00%
#   Class XBB: 100.00%
#   Class B.1.1: 100.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 99.00%
#   Class B.1: 100.00%
#   Class EG.5.1: 2.86%
#   Class B.1.617.2: 100.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class C.37: 99.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 100.00%
#   Class B.1.351: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 98.04%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['AGATCGCTT', 'AGATTGTTT', 'AGATTGTTA', 'AGATCGTTT'], Key: (1360, 'AGATTGTTT'), K-mer: AGATTGTTA, Gene: S
# Percentages of AGATTGTTA at key (1360, 'AGATTGTTT'):
#   Class EG.5.1: 85.71%
#
# K-mer variations: ['AGATCGCTT', 'AGATTGTTT', 'AGATTGTTA', 'AGATCGTTT'], Key: (1360, 'AGATTGTTT'), K-mer: AGATCGTTT, Gene: S
# Percentages of AGATCGTTT at key (1360, 'AGATTGTTT'):
#   Class JN.1: 98.00%
#   Class BA.2.86.1: 18.00%
#
# K-mer variations: ['ATAACCAGA', 'ACAAACAGA', 'AGAACCAGA', 'ACAACCAGA', 'ATAACTACA'], Key: (55, 'ACAACCAGA'), K-mer: ATAACCAGA, Gene: S
# Percentages of ATAACCAGA at key (55, 'ACAACCAGA'):
#   Class B.1.1.7: 1.00%
#   Class BA.2.12.1: 100.00%
#   Class BA.2: 99.00%
#   Class XBB.2.3: 97.00%
#   Class XBB: 100.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 100.00%
#   Class EG.5.1: 94.29%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class B.1.525: 1.00%
#   Class BA.5: 100.00%
#   Class B.1.1.529: 28.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 99.00%
#
# K-mer variations: ['ATAACCAGA', 'ACAAACAGA', 'AGAACCAGA', 'ACAACCAGA', 'ATAACTACA'], Key: (55, 'ACAACCAGA'), K-mer: ACAAACAGA, Gene: S
# Percentages of ACAAACAGA at key (55, 'ACAACCAGA'):
#   Class P.1: 98.00%
#
# K-mer variations: ['ATAACCAGA', 'ACAAACAGA', 'AGAACCAGA', 'ACAACCAGA', 'ATAACTACA'], Key: (55, 'ACAACCAGA'), K-mer: AGAACCAGA, Gene: S
# Percentages of AGAACCAGA at key (55, 'ACAACCAGA'):
#   Class B.1.617.2: 98.00%
#   Class B.1.1.529: 2.00%
#
# K-mer variations: ['ATAACCAGA', 'ACAAACAGA', 'AGAACCAGA', 'ACAACCAGA', 'ATAACTACA'], Key: (55, 'ACAACCAGA'), K-mer: ACAACCAGA, Gene: S
# Percentages of ACAACCAGA at key (55, 'ACAACCAGA'):
#   Class B.1.1.7: 99.00%
#   Class BA.1: 100.00%
#   Class B.1.2: 99.00%
#   Class XBB.2.3: 2.00%
#   Class B.1.1: 99.00%
#   Class B.1: 100.00%
#   Class B.1.617.2: 1.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 2.00%
#   Class B.1.621: 94.74%
#   Class B.1.427: 91.00%
#   Class B.1.177: 99.00%
#   Class B.1.525: 99.00%
#   Class B.1.351: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 70.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['ATAACCAGA', 'ACAAACAGA', 'AGAACCAGA', 'ACAACCAGA', 'ATAACTACA'], Key: (55, 'ACAACCAGA'), K-mer: ATAACTACA, Gene: S
# Percentages of ATAACTACA at key (55, 'ACAACCAGA'):
#   Class JN.1: 99.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.2.86.1: 100.00%
#
# K-mer variations: ['CCAAATATC', 'CCAAATACT', 'CCAAATACC'], Key: (6013, 'CCAAATACC'), K-mer: CCAAATATC, Gene: ORF1a
# Percentages of CCAAATATC at key (6013, 'CCAAATACC'):
#   Class B.1: 1.00%
#   Class B.1.429: 1.00%
#   Class B.1.525: 99.00%
#
# K-mer variations: ['CCAAATATC', 'CCAAATACT', 'CCAAATACC'], Key: (6013, 'CCAAATACC'), K-mer: CCAAATACT, Gene: ORF1a
# Percentages of CCAAATACT at key (6013, 'CCAAATACC'):
#   Class B.1.427: 1.00%
#   Class B.1.177: 100.00%
#
# K-mer variations: ['CCAAATATC', 'CCAAATACT', 'CCAAATACC'], Key: (6013, 'CCAAATACC'), K-mer: CCAAATACC, Gene: ORF1a
# Percentages of CCAAATACC at key (6013, 'CCAAATACC'):
#   Class B.1.1.7: 100.00%
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.1: 100.00%
#   Class BA.2.12.1: 100.00%
#   Class B.1.2: 100.00%
#   Class BA.2: 100.00%
#   Class BA.2.86.1: 100.00%
#   Class XBB.2.3: 100.00%
#   Class XBB: 98.95%
#   Class B.1.1: 99.00%
#   Class CH.1.1: 99.00%
#   Class XBB.1.5: 98.00%
#   Class B.1: 99.00%
#   Class EG.5.1: 100.00%
#   Class B.1.617.2: 100.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 99.00%
#   Class BA.4: 99.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 99.00%
#   Class B.1.525: 1.00%
#   Class B.1.351: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['ATGTCTGAT', 'ATGTCTCTA', 'ATGTAT---'], Key: (1, 'ATGTCTGAT'), K-mer: ATGTCTGAT, Gene: N
# Percentages of ATGTCTGAT at key (1, 'ATGTCTGAT'):
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.1: 100.00%
#   Class BA.2.12.1: 100.00%
#   Class B.1.2: 100.00%
#   Class BA.2: 100.00%
#   Class BA.2.86.1: 100.00%
#   Class XBB.2.3: 100.00%
#   Class XBB: 100.00%
#   Class B.1.1: 95.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 100.00%
#   Class B.1: 99.00%
#   Class EG.5.1: 100.00%
#   Class B.1.617.2: 100.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 2.00%
#   Class B.1.351: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 96.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['ATGTCTGAT', 'ATGTCTCTA', 'ATGTAT---'], Key: (1, 'ATGTCTGAT'), K-mer: ATGTCTCTA, Gene: N
# Percentages of ATGTCTCTA at key (1, 'ATGTCTGAT'):
#   Class B.1.1.7: 100.00%
#   Class B.1.1: 4.00%
#
# K-mer variations: ['ATGTCTGAT', 'ATGTCTCTA', 'ATGTAT---'], Key: (1, 'ATGTCTGAT'), K-mer: ATGTAT---, Gene: N
# Percentages of ATGTAT--- at key (1, 'ATGTCTGAT'):
#   Class B.1.525: 98.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: GCAGGTTCT, Gene: S
# Percentages of GCAGGTTCT at key (1450, 'GAAGGTTTT'):
#   Class XBB: 76.84%
#   Class CH.1.1: 99.00%
#   Class XBB.1.5: 2.00%
#   Class BA.2.75: 1.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: GAAGGTTTT, Gene: S
# Percentages of GAAGGTTTT at key (1450, 'GAAGGTTTT'):
#   Class B.1.1.7: 100.00%
#   Class BA.1: 2.00%
#   Class B.1.2: 100.00%
#   Class XBB: 1.05%
#   Class B.1.1: 99.00%
#   Class B.1: 96.00%
#   Class B.1.617.2: 100.00%
#   Class B.1.526: 38.00%
#   Class B.1.429: 99.00%
#   Class C.37: 100.00%
#   Class P.1: 3.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 1.00%
#   Class B.1.351: 1.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.1.529: 83.00%
#   Class D.2: 99.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: AAAGGTCCT, Gene: S
# Percentages of AAAGGTCCT at key (1450, 'GAAGGTTTT'):
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.2.86.1: 100.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: CAAGGTTTT, Gene: S
# Percentages of CAAGGTTTT at key (1450, 'GAAGGTTTT'):
#   Class B.1.617.1: 100.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: GCAGGTTTT, Gene: S
# Percentages of GCAGGTTTT at key (1450, 'GAAGGTTTT'):
#   Class BA.1: 98.00%
#   Class BA.2.12.1: 100.00%
#   Class BA.2: 100.00%
#   Class XBB: 8.42%
#   Class B.1.1.529: 15.00%
#   Class BA.2.75: 87.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: GCAGGTCCT, Gene: S
# Percentages of GCAGGTCCT at key (1450, 'GAAGGTTTT'):
#   Class XBB.2.3: 99.00%
#   Class XBB: 7.37%
#   Class XBB.1.5: 91.00%
#   Class EG.5.1: 88.57%
#   Class XBB.1.16: 100.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: GCAGGTGTT, Gene: S
# Percentages of GCAGGTGTT at key (1450, 'GAAGGTTTT'):
#   Class BA.4: 96.00%
#   Class BQ.1: 100.00%
#   Class BA.5: 99.00%
#   Class B.1.1.529: 2.00%
#   Class BA.2.75: 7.00%
#
# K-mer variations: ['GCAGGTTCT', 'GAAGGTTTT', 'AAAGGTCCT', 'CAAGGTTTT', 'GCAGGTTTT', 'GCAGGTCCT', 'GCAGGTGTT', 'AAAGGTTTT'], Key: (1450, 'GAAGGTTTT'), K-mer: AAAGGTTTT, Gene: S
# Percentages of AAAGGTTTT at key (1450, 'GAAGGTTTT'):
#   Class B.1.1: 1.00%
#   Class B.1: 4.00%
#   Class B.1.526: 62.00%
#   Class P.1: 97.00%
#   Class B.1.621: 94.74%
#   Class B.1.525: 99.00%
#   Class B.1.351: 99.00%
#
# K-mer variations: ['TTTAAGGTT', 'CTTAAGGTT', 'CTTAGGGTT'], Key: (10054, 'CTTAAGGTT'), K-mer: TTTAAGGTT, Gene: ORF1a
# Percentages of TTTAAGGTT at key (10054, 'CTTAAGGTT'):
#   Class BA.2.12.1: 1.00%
#   Class B.1.2: 99.00%
#   Class P.1: 2.00%
#
# K-mer variations: ['TTTAAGGTT', 'CTTAAGGTT', 'CTTAGGGTT'], Key: (10054, 'CTTAAGGTT'), K-mer: CTTAAGGTT, Gene: ORF1a
# Percentages of CTTAAGGTT at key (10054, 'CTTAAGGTT'):
#   Class B.1.1.7: 100.00%
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.1: 100.00%
#   Class BA.2.12.1: 99.00%
#   Class B.1.2: 1.00%
#   Class BA.2: 100.00%
#   Class BA.2.86.1: 99.00%
#   Class XBB.2.3: 99.00%
#   Class XBB: 100.00%
#   Class B.1.1: 97.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 96.00%
#   Class B.1: 99.00%
#   Class EG.5.1: 100.00%
#   Class B.1.617.2: 99.00%
#   Class B.1.526: 98.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 97.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 98.00%
#   Class B.1.177: 99.00%
#   Class B.1.525: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 98.00%
#   Class B.1.617.1: 95.95%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 98.04%
#   Class BA.2.75: 100.00%
#   Class D.2: 99.00%
#
# K-mer variations: ['TTTAAGGTT', 'CTTAAGGTT', 'CTTAGGGTT'], Key: (10054, 'CTTAAGGTT'), K-mer: CTTAGGGTT, Gene: ORF1a
# Percentages of CTTAGGGTT at key (10054, 'CTTAAGGTT'):
#   Class BA.2.86.1: 1.00%
#   Class XBB.2.3: 1.00%
#   Class B.1.1: 3.00%
#   Class B.1.617.2: 1.00%
#   Class B.1.526: 2.00%
#   Class P.1: 1.00%
#   Class B.1.427: 1.00%
#   Class B.1.177: 1.00%
#   Class B.1.351: 99.00%
#   Class B.1.1.1: 1.00%
#   Class B.1.617.1: 4.05%
#   Class XBB.1.16: 1.96%
#   Class D.2: 1.00%
#
# K-mer variations: ['CGTGATCTC', 'CGTGAGCCAGAAGATCTC', 'CGTGATTTC', 'CGTGGTCTC'], Key: (640, 'CGTGATCTC'), K-mer: CGTGATCTC, Gene: S
# Percentages of CGTGATCTC at key (640, 'CGTGATCTC'):
#   Class B.1.1.7: 100.00%
#   Class BA.1: 4.00%
#   Class BA.2.12.1: 99.00%
#   Class B.1.2: 100.00%
#   Class BA.2: 100.00%
#   Class XBB.2.3: 99.00%
#   Class XBB: 100.00%
#   Class B.1.1: 100.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 99.00%
#   Class B.1: 100.00%
#   Class EG.5.1: 88.57%
#   Class B.1.617.2: 100.00%
#   Class B.1.526: 99.00%
#   Class B.1.429: 99.00%
#   Class BA.4: 99.00%
#   Class BQ.1: 99.00%
#   Class C.37: 100.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 97.00%
#   Class B.1.525: 95.00%
#   Class B.1.351: 4.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 99.00%
#   Class B.1.617.1: 98.65%
#   Class B.1.1.529: 62.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['CGTGATCTC', 'CGTGAGCCAGAAGATCTC', 'CGTGATTTC', 'CGTGGTCTC'], Key: (640, 'CGTGATCTC'), K-mer: CGTGAGCCAGAAGATCTC, Gene: S
# Percentages of CGTGAGCCAGAAGATCTC at key (640, 'CGTGATCTC'):
#   Class BA.1: 95.00%
#   Class B.1.1.529: 38.00%
#
# K-mer variations: ['CGTGATCTC', 'CGTGAGCCAGAAGATCTC', 'CGTGATTTC', 'CGTGGTCTC'], Key: (640, 'CGTGATCTC'), K-mer: CGTGATTTC, Gene: S
# Percentages of CGTGATTTC at key (640, 'CGTGATCTC'):
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.2.12.1: 1.00%
#   Class BA.2.86.1: 100.00%
#   Class B.1.526: 1.00%
#   Class BA.4: 1.00%
#   Class B.1.177: 2.00%
#   Class B.1.617.1: 1.35%
#
# K-mer variations: ['CGTGATCTC', 'CGTGAGCCAGAAGATCTC', 'CGTGATTTC', 'CGTGGTCTC'], Key: (640, 'CGTGATCTC'), K-mer: CGTGGTCTC, Gene: S
# Percentages of CGTGGTCTC at key (640, 'CGTGATCTC'):
#   Class B.1.351: 96.00%
#
# K-mer variations: ['GAAAGT---', 'GAAAGTGAG', 'AAAAGTGAG'], Key: (460, 'GAAAGTGAG'), K-mer: GAAAGT---, Gene: S
# Percentages of GAAAGT--- at key (460, 'GAAAGTGAG'):
#   Class BA.1: 1.00%
#   Class B.1.617.2: 98.00%
#
# K-mer variations: ['GAAAGT---', 'GAAAGTGAG', 'AAAAGTGAG'], Key: (460, 'GAAAGTGAG'), K-mer: GAAAGTGAG, Gene: S
# Percentages of GAAAGTGAG at key (460, 'GAAAGTGAG'):
#   Class B.1.1.7: 100.00%
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 100.00%
#   Class BA.1: 99.00%
#   Class BA.2.12.1: 100.00%
#   Class B.1.2: 100.00%
#   Class BA.2: 100.00%
#   Class BA.2.86.1: 100.00%
#   Class XBB.2.3: 100.00%
#   Class XBB: 100.00%
#   Class B.1.1: 100.00%
#   Class CH.1.1: 100.00%
#   Class XBB.1.5: 100.00%
#   Class B.1: 100.00%
#   Class EG.5.1: 100.00%
#   Class B.1.617.2: 2.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 99.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 100.00%
#   Class B.1.351: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 33.78%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 100.00%
#   Class BA.2.75: 100.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['GAAAGT---', 'GAAAGTGAG', 'AAAAGTGAG'], Key: (460, 'GAAAGTGAG'), K-mer: AAAAGTGAG, Gene: S
# Percentages of AAAAGTGAG at key (460, 'GAAAGTGAG'):
#   Class B.1.617.1: 66.22%
#
# K-mer variations: ['TTCAGAGTT', 'TCAGGAGTT', 'TTAAGAGTT', '---GGAGTT'], Key: (469, 'TTCAGAGTT'), K-mer: TTCAGAGTT, Gene: S
# Percentages of TTCAGAGTT at key (469, 'TTCAGAGTT'):
#   Class B.1.1.7: 100.00%
#   Class BA.1: 99.00%
#   Class BA.2.12.1: 100.00%
#   Class B.1.2: 100.00%
#   Class BA.2: 100.00%
#   Class XBB.2.3: 99.00%
#   Class XBB: 92.63%
#   Class B.1.1: 97.00%
#   Class XBB.1.5: 92.00%
#   Class B.1: 100.00%
#   Class EG.5.1: 91.43%
#   Class B.1.617.2: 2.00%
#   Class B.1.526: 100.00%
#   Class B.1.429: 100.00%
#   Class BA.4: 100.00%
#   Class BQ.1: 100.00%
#   Class C.37: 100.00%
#   Class P.1: 100.00%
#   Class B.1.621: 100.00%
#   Class B.1.427: 100.00%
#   Class B.1.177: 100.00%
#   Class B.1.525: 100.00%
#   Class B.1.351: 100.00%
#   Class BA.5: 100.00%
#   Class B.1.1.1: 100.00%
#   Class B.1.617.1: 100.00%
#   Class B.1.1.529: 100.00%
#   Class XBB.1.16: 98.04%
#   Class BA.2.75: 1.00%
#   Class D.2: 100.00%
#
# K-mer variations: ['TTCAGAGTT', 'TCAGGAGTT', 'TTAAGAGTT', '---GGAGTT'], Key: (469, 'TTCAGAGTT'), K-mer: TCAGGAGTT, Gene: S
# Percentages of TCAGGAGTT at key (469, 'TTCAGAGTT'):
#   Class JN.1: 100.00%
#   Class JN.1.11.1: 98.00%
#   Class BA.2.86.1: 100.00%
#
# K-mer variations: ['TTCAGAGTT', 'TCAGGAGTT', 'TTAAGAGTT', '---GGAGTT'], Key: (469, 'TTCAGAGTT'), K-mer: TTAAGAGTT, Gene: S
# Percentages of TTAAGAGTT at key (469, 'TTCAGAGTT'):
#   Class XBB: 1.05%
#   Class CH.1.1: 99.00%
#   Class BA.2.75: 96.00%
#
# K-mer variations: ['TTCAGAGTT', 'TCAGGAGTT', 'TTAAGAGTT', '---GGAGTT'], Key: (469, 'TTCAGAGTT'), K-mer: ---GGAGTT, Gene: S
# Percentages of ---GGAGTT at key (469, 'TTCAGAGTT'):
#   Class BA.1: 1.00%
#   Class B.1.617.2: 98.00%
#
#
# Processing: Human_immunodeficiency_virus_1
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: CTCATGATC, Gene: env
# Percentages of CTCATGATC at key (55, 'ACCATGCTC'):
#   Class 11_cpx: 90.48%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ATTATGCTC, Gene: env
# Percentages of ATTATGCTC at key (55, 'ACCATGCTC'):
#   Class D: 1.61%
#   Class 63_02A6: 50.00%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ACTATGATC, Gene: env
# Percentages of ACTATGATC at key (55, 'ACCATGCTC'):
#   Class 02_AG: 1.00%
#   Class A1: 25.00%
#   Class D: 1.61%
#   Class 35_A1D: 71.43%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ---------, Gene: env
# Percentages of --------- at key (55, 'ACCATGCTC'):
#   Class 02_AG: 2.00%
#   Class A1: 7.00%
#   Class 01_AE: 56.00%
#   Class B: 8.00%
#   Class G: 4.48%
#   Class C: 1.00%
#   Class D: 1.61%
#   Class F1: 1.75%
#   Class O: 24.14%
#   Class 35_A1D: 9.52%
#   Class A6: 89.00%
#   Class 63_02A6: 15.38%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: CTTTTATTC, Gene: env
# Percentages of CTTTTATTC at key (55, 'ACCATGCTC'):
#   Class F1: 77.19%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ACCATGCTC, Gene: env
# Percentages of ACCATGCTC at key (55, 'ACCATGCTC'):
#   Class B: 15.00%
#   Class D: 40.32%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: GTCTTAGGC, Gene: env
# Percentages of GTCTTAGGC at key (55, 'ACCATGCTC'):
#   Class 08_BC: 70.00%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ATCTTAGGC, Gene: env
# Percentages of ATCTTAGGC at key (55, 'ACCATGCTC'):
#   Class C: 69.00%
#   Class 08_BC: 26.67%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ACTTTGATC, Gene: env
# Percentages of ACTTTGATC at key (55, 'ACCATGCTC'):
#   Class 01_AE: 33.00%
#   Class G: 55.22%
#   Class 20_BG: 11.54%
#
# K-mer variations: ['CTCATGATC', 'ATTATGCTC', 'ACTATGATC', '---------', 'CTTTTATTC', 'ACCATGCTC', 'GTCTTAGGC', 'ATCTTAGGC', 'ACTTTGATC', 'ATTTTGATC'], Key: (55, 'ACCATGCTC'), K-mer: ATTTTGATC, Gene: env
# Percentages of ATTTTGATC at key (55, 'ACCATGCTC'):
#   Class 01_AE: 6.00%
#   Class G: 8.96%
#   Class 20_BG: 88.46%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATAGAGGCT, Gene: env
# Percentages of ATAGAGGCT at key (1675, 'ATTGAGGCG'):
#   Class 02_AG: 93.00%
#   Class A1: 95.00%
#   Class G: 1.49%
#   Class 35_A1D: 95.24%
#   Class A6: 98.00%
#   Class 63_02A6: 100.00%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATTGAAGCG, Gene: env
# Percentages of ATTGAAGCG at key (1675, 'ATTGAGGCG'):
#   Class F1: 87.72%
#   Class 11_cpx: 9.52%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATTGAGGCA, Gene: env
# Percentages of ATTGAGGCA at key (1675, 'ATTGAGGCG'):
#   Class 11_cpx: 33.33%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATTGAGGCG, Gene: env
# Percentages of ATTGAGGCG at key (1675, 'ATTGAGGCG'):
#   Class 01_AE: 4.00%
#   Class B: 90.00%
#   Class C: 1.00%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATAGAGGCG, Gene: env
# Percentages of ATAGAGGCG at key (1675, 'ATTGAGGCG'):
#   Class 01_AE: 94.00%
#   Class G: 77.61%
#   Class C: 94.00%
#   Class D: 91.94%
#   Class 08_BC: 93.33%
#   Class 20_BG: 100.00%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATACAGGCC, Gene: env
# Percentages of ATACAGGCC at key (1675, 'ATTGAGGCG'):
#   Class O: 93.10%
#
# K-mer variations: ['ATAGAGGCT', 'ATTGAAGCG', 'ATTGAGGCA', 'ATTGAGGCG', 'ATAGAGGCG', 'ATACAGGCC', 'ATCGAGGCA'], Key: (1675, 'ATTGAGGCG'), K-mer: ATCGAGGCA, Gene: env
# Percentages of ATCGAGGCA at key (1675, 'ATTGAGGCG'):
#   Class 11_cpx: 33.33%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: GGGTCTGCC, Gene: gag-pol
# Percentages of GGGTCTGCC at key (3167, 'AGGGGTGCC'):
#   Class 02_AG: 1.00%
#   Class G: 80.60%
#   Class A6: 2.00%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AGGTCTGCT, Gene: gag-pol
# Percentages of AGGTCTGCT at key (3167, 'AGGGGTGCC'):
#   Class 02_AG: 10.00%
#   Class A1: 62.00%
#   Class 01_AE: 78.00%
#   Class F1: 8.77%
#   Class 35_A1D: 85.71%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AGGGGTGCC, Gene: gag-pol
# Percentages of AGGGGTGCC at key (3167, 'AGGGGTGCC'):
#   Class B: 52.00%
#   Class D: 50.00%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: GGGTCTGCT, Gene: gag-pol
# Percentages of GGGTCTGCT at key (3167, 'AGGGGTGCC'):
#   Class 01_AE: 1.00%
#   Class A6: 77.00%
#   Class 63_02A6: 80.77%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AAGGCCTCC, Gene: gag-pol
# Percentages of AAGGCCTCC at key (3167, 'AGGGGTGCC'):
#   Class O: 34.48%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AAAAGTGCC, Gene: gag-pol
# Percentages of AAAAGTGCC at key (3167, 'AGGGGTGCC'):
#   Class 20_BG: 96.15%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AGGTCTGCC, Gene: gag-pol
# Percentages of AGGTCTGCC at key (3167, 'AGGGGTGCC'):
#   Class 02_AG: 70.00%
#   Class A1: 3.00%
#   Class 01_AE: 11.00%
#   Class C: 2.00%
#   Class F1: 66.67%
#
# K-mer variations: ['GGGTCTGCC', 'AGGTCTGCT', 'AGGGGTGCC', 'GGGTCTGCT', 'AAGGCCTCC', 'AAAAGTGCC', 'AGGTCTGCC', 'AGGACTGCC'], Key: (3167, 'AGGGGTGCC'), K-mer: AGGACTGCC, Gene: gag-pol
# Percentages of AGGACTGCC at key (3167, 'AGGGGTGCC'):
#   Class C: 61.00%
#   Class F1: 1.75%
#   Class 08_BC: 80.00%
#   Class 11_cpx: 66.67%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCTTTCAGT, Gene: gag
# Percentages of GCTTTCAGT at key (487, 'GCTTTCAGC'):
#   Class 02_AG: 9.00%
#   Class A1: 2.00%
#   Class B: 5.00%
#   Class G: 7.46%
#   Class C: 3.00%
#   Class A6: 1.00%
#   Class 20_BG: 88.46%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCCTTTAGC, Gene: gag
# Percentages of GCCTTTAGC at key (487, 'GCTTTCAGC'):
#   Class B: 3.00%
#   Class G: 4.48%
#   Class C: 7.00%
#   Class F1: 42.11%
#   Class 08_BC: 3.33%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GGTTTTAAC, Gene: gag
# Percentages of GGTTTTAAC at key (487, 'GCTTTCAGC'):
#   Class 02_AG: 1.00%
#   Class A1: 3.00%
#   Class 01_AE: 75.00%
#   Class F1: 1.75%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCCTTCAGT, Gene: gag
# Percentages of GCCTTCAGT at key (487, 'GCTTTCAGC'):
#   Class G: 70.15%
#   Class 20_BG: 11.54%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCTTTCAGC, Gene: gag
# Percentages of GCTTTCAGC at key (487, 'GCTTTCAGC'):
#   Class 02_AG: 39.00%
#   Class A1: 20.00%
#   Class B: 68.00%
#   Class C: 30.00%
#   Class D: 53.23%
#   Class F1: 1.75%
#   Class 35_A1D: 76.19%
#   Class A6: 80.00%
#   Class 11_cpx: 90.48%
#   Class 63_02A6: 7.69%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCCTTTAAC, Gene: gag
# Percentages of GCCTTTAAC at key (487, 'GCTTTCAGC'):
#   Class O: 100.00%
#
# K-mer variations: ['GCTTTCAGT', 'GCCTTTAGC', 'GGTTTTAAC', 'GCCTTCAGT', 'GCTTTCAGC', 'GCCTTTAAC', 'GCTTTTAGC'], Key: (487, 'GCTTTCAGC'), K-mer: GCTTTTAGC, Gene: gag
# Percentages of GCTTTTAGC at key (487, 'GCTTTCAGC'):
#   Class 02_AG: 27.00%
#   Class A1: 15.00%
#   Class B: 14.00%
#   Class G: 1.49%
#   Class C: 45.00%
#   Class D: 19.35%
#   Class F1: 52.63%
#   Class 35_A1D: 4.76%
#   Class 08_BC: 96.67%
#   Class A6: 7.00%
#   Class 11_cpx: 4.76%
#   Class 63_02A6: 84.62%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAGAGCAA, Gene: gag
# Percentages of GAAGAGCAA at key (316, 'GAAGAGCAA'):
#   Class 02_AG: 2.00%
#   Class B: 84.00%
#   Class C: 3.00%
#   Class D: 6.45%
#   Class F1: 35.09%
#   Class 08_BC: 3.33%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAGAACAA, Gene: gag
# Percentages of GAAGAACAA at key (316, 'GAAGAGCAA'):
#   Class 01_AE: 9.00%
#   Class B: 4.00%
#   Class C: 82.00%
#   Class D: 82.26%
#   Class F1: 42.11%
#   Class 08_BC: 93.33%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAGTACAA, Gene: gag
# Percentages of GAAGTACAA at key (316, 'GAAGAGCAA'):
#   Class 02_AG: 19.00%
#   Class A1: 1.00%
#   Class 01_AE: 57.00%
#   Class 11_cpx: 4.76%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAGTAATG, Gene: gag
# Percentages of GAAGTAATG at key (316, 'GAAGAGCAA'):
#   Class O: 51.72%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: AAGTTACAA, Gene: gag
# Percentages of AAGTTACAA at key (316, 'GAAGAGCAA'):
#   Class 20_BG: 100.00%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAGTGCAA, Gene: gag
# Percentages of GAAGTGCAA at key (316, 'GAAGAGCAA'):
#   Class 02_AG: 3.00%
#   Class 01_AE: 1.00%
#   Class 63_02A6: 69.23%
#
# K-mer variations: ['GAAGAGCAA', 'GAAGAACAA', 'GAAGTACAA', 'GAAGTAATG', 'AAGTTACAA', 'GAAGTGCAA', 'GAAATACAA'], Key: (316, 'GAAGAGCAA'), K-mer: GAAATACAA, Gene: gag
# Percentages of GAAATACAA at key (316, 'GAAGAGCAA'):
#   Class 02_AG: 24.00%
#   Class A1: 53.00%
#   Class 01_AE: 2.00%
#   Class G: 2.99%
#   Class C: 1.00%
#   Class 35_A1D: 85.71%
#   Class A6: 65.00%
#   Class 11_cpx: 71.43%
#   Class 63_02A6: 7.69%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: ATTGTTTCC, Gene: gag-pol
# Percentages of ATTGTTTCC at key (3491, 'GTTGTCACC'):
#   Class 02_AG: 1.00%
#   Class A1: 5.00%
#   Class C: 2.00%
#   Class 08_BC: 76.67%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTTGTCTCC, Gene: gag-pol
# Percentages of GTTGTCTCC at key (3491, 'GTTGTCACC'):
#   Class 02_AG: 3.00%
#   Class A1: 1.00%
#   Class B: 42.00%
#   Class D: 1.61%
#   Class F1: 5.26%
#   Class 08_BC: 6.67%
#   Class 20_BG: 3.85%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTTGTTCCT, Gene: gag-pol
# Percentages of GTTGTTCCT at key (3491, 'GTTGTCACC'):
#   Class 02_AG: 1.00%
#   Class B: 1.00%
#   Class C: 4.00%
#   Class D: 1.61%
#   Class A6: 55.00%
#   Class 63_02A6: 3.85%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: ATAATAAAA, Gene: gag-pol
# Percentages of ATAATAAAA at key (3491, 'GTTGTCACC'):
#   Class O: 55.17%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTTGTCTCT, Gene: gag-pol
# Percentages of GTTGTCTCT at key (3491, 'GTTGTCACC'):
#   Class B: 4.00%
#   Class D: 43.55%
#   Class A6: 2.00%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTTGTTTCC, Gene: gag-pol
# Percentages of GTTGTTTCC at key (3491, 'GTTGTCACC'):
#   Class 02_AG: 64.00%
#   Class A1: 72.00%
#   Class B: 2.00%
#   Class C: 1.00%
#   Class 35_A1D: 71.43%
#   Class 08_BC: 10.00%
#   Class A6: 1.00%
#   Class 63_02A6: 38.46%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTGGTTACC, Gene: gag-pol
# Percentages of GTGGTTACC at key (3491, 'GTTGTCACC'):
#   Class 11_cpx: 57.14%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTAGTTTCC, Gene: gag-pol
# Percentages of GTAGTTTCC at key (3491, 'GTTGTCACC'):
#   Class 01_AE: 75.00%
#   Class A6: 2.00%
#
# K-mer variations: ['ATTGTTTCC', 'GTTGTCTCC', 'GTTGTTCCT', 'ATAATAAAA', 'GTTGTCTCT', 'GTTGTTTCC', 'GTGGTTACC', 'GTAGTTTCC', 'GTTATCTAT'], Key: (3491, 'GTTGTCACC'), K-mer: GTTATCTAT, Gene: gag-pol
# Percentages of GTTATCTAT at key (3491, 'GTTGTCACC'):
#   Class 20_BG: 88.46%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CACTTT---, Gene: env
# Percentages of CACTTT--- at key (1054, 'CAATTTGGA'):
#   Class 02_AG: 18.00%
#   Class A1: 13.00%
#   Class 01_AE: 65.00%
#   Class B: 4.00%
#   Class G: 1.49%
#   Class C: 6.00%
#   Class 08_BC: 3.33%
#   Class A6: 30.00%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CACTGG---, Gene: env
# Percentages of CACTGG--- at key (1054, 'CAATTTGGA'):
#   Class A1: 1.00%
#   Class 35_A1D: 95.24%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CACTTC---, Gene: env
# Percentages of CACTTC--- at key (1054, 'CAATTTGGA'):
#   Class 01_AE: 2.00%
#   Class C: 56.00%
#   Class 08_BC: 83.33%
#   Class A6: 1.00%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: AGCTACAAC, Gene: env
# Percentages of AGCTACAAC at key (1054, 'CAATTTGGA'):
#   Class G: 1.49%
#   Class 20_BG: 96.15%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CTTGTAAAC, Gene: env
# Percentages of CTTGTAAAC at key (1054, 'CAATTTGGA'):
#   Class O: 34.48%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CAATTT---, Gene: env
# Percentages of CAATTT--- at key (1054, 'CAATTTGGA'):
#   Class 02_AG: 1.00%
#   Class 01_AE: 3.00%
#   Class B: 33.00%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: TACTTT---, Gene: env
# Percentages of TACTTT--- at key (1054, 'CAATTTGGA'):
#   Class 02_AG: 13.00%
#   Class A1: 18.00%
#   Class 01_AE: 4.00%
#   Class A6: 49.00%
#   Class 63_02A6: 3.85%
#
# K-mer variations: ['CACTTT---', 'CACTGG---', 'CACTTC---', 'AGCTACAAC', 'CTTGTAAAC', 'CAATTT---', 'TACTTT---', 'CATTTT---'], Key: (1054, 'CAATTTGGA'), K-mer: CATTTT---, Gene: env
# Percentages of CATTTT--- at key (1054, 'CAATTTGGA'):
#   Class 02_AG: 2.00%
#   Class A1: 2.00%
#   Class 01_AE: 5.00%
#   Class B: 2.00%
#   Class C: 1.00%
#   Class F1: 33.33%
#   Class 63_02A6: 69.23%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AATAACGAT, Gene: gag-pol
# Percentages of AATAACGAT at key (4535, 'AATAGTGAC'):
#   Class C: 2.00%
#   Class A6: 79.00%
#   Class 11_cpx: 4.76%
#   Class 63_02A6: 92.31%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AACAGTGAC, Gene: gag-pol
# Percentages of AACAGTGAC at key (4535, 'AATAGTGAC'):
#   Class A1: 2.00%
#   Class 01_AE: 2.00%
#   Class B: 5.00%
#   Class C: 41.00%
#   Class D: 14.52%
#   Class 35_A1D: 4.76%
#   Class 08_BC: 6.67%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AATAGTGAA, Gene: gag-pol
# Percentages of AATAGTGAA at key (4535, 'AATAGTGAC'):
#   Class 02_AG: 4.00%
#   Class A1: 3.00%
#   Class B: 24.00%
#   Class G: 8.96%
#   Class D: 33.87%
#   Class F1: 96.49%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AATAGTGAT, Gene: gag-pol
# Percentages of AATAGTGAT at key (4535, 'AATAGTGAC'):
#   Class 02_AG: 64.00%
#   Class A1: 44.00%
#   Class 01_AE: 74.00%
#   Class B: 7.00%
#   Class G: 1.49%
#   Class C: 7.00%
#   Class D: 16.13%
#   Class 35_A1D: 76.19%
#   Class A6: 3.00%
#   Class 11_cpx: 71.43%
#   Class 63_02A6: 3.85%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AAAGGAGAC, Gene: gag-pol
# Percentages of AAAGGAGAC at key (4535, 'AATAGTGAC'):
#   Class O: 44.83%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AATAACGAA, Gene: gag-pol
# Percentages of AATAACGAA at key (4535, 'AATAGTGAC'):
#   Class G: 74.63%
#   Class 20_BG: 11.54%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AATAGTGAC, Gene: gag-pol
# Percentages of AATAGTGAC at key (4535, 'AATAGTGAC'):
#   Class 02_AG: 3.00%
#   Class A1: 2.00%
#   Class 01_AE: 14.00%
#   Class B: 55.00%
#   Class C: 36.00%
#   Class D: 30.65%
#   Class 35_A1D: 14.29%
#   Class 08_BC: 93.33%
#
# K-mer variations: ['AATAACGAT', 'AACAGTGAC', 'AATAGTGAA', 'AATAGTGAT', 'AAAGGAGAC', 'AATAACGAA', 'AATAGTGAC', 'AGTAATGAA'], Key: (4535, 'AATAGTGAC'), K-mer: AGTAATGAA, Gene: gag-pol
# Percentages of AGTAATGAA at key (4535, 'AATAGTGAC'):
#   Class 20_BG: 88.46%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: CTACCTATA, Gene: gag-pol
# Percentages of CTACCTATA at key (3266, 'CTGCCCATA'):
#   Class 02_AG: 7.00%
#   Class A1: 1.00%
#   Class 01_AE: 2.00%
#   Class B: 3.00%
#   Class G: 74.63%
#   Class D: 1.61%
#   Class 35_A1D: 4.76%
#   Class A6: 2.00%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: CTACCCATA, Gene: gag-pol
# Percentages of CTACCCATA at key (3266, 'CTGCCCATA'):
#   Class 02_AG: 75.00%
#   Class A1: 66.00%
#   Class 01_AE: 84.00%
#   Class B: 66.00%
#   Class G: 8.96%
#   Class D: 69.35%
#   Class F1: 56.14%
#   Class 35_A1D: 80.95%
#   Class A6: 80.00%
#   Class 11_cpx: 71.43%
#   Class 63_02A6: 19.23%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: TTACCAATC, Gene: gag-pol
# Percentages of TTACCAATC at key (3266, 'CTGCCCATA'):
#   Class 08_BC: 96.67%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: TTACCCATA, Gene: gag-pol
# Percentages of TTACCCATA at key (3266, 'CTGCCCATA'):
#   Class 02_AG: 10.00%
#   Class A1: 20.00%
#   Class 01_AE: 7.00%
#   Class B: 19.00%
#   Class C: 1.00%
#   Class D: 1.61%
#   Class F1: 42.11%
#   Class 35_A1D: 9.52%
#   Class A6: 4.00%
#   Class 11_cpx: 14.29%
#   Class 63_02A6: 73.08%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: TTACCTATA, Gene: gag-pol
# Percentages of TTACCTATA at key (3266, 'CTGCCCATA'):
#   Class A1: 1.00%
#   Class B: 3.00%
#   Class G: 8.96%
#   Class D: 1.61%
#   Class 20_BG: 100.00%
#
# K-mer variations: ['CTACCTATA', 'CTACCCATA', 'TTACCAATC', 'TTACCCATA', 'TTACCTATA', 'CTACCCATC'], Key: (3266, 'CTGCCCATA'), K-mer: CTACCCATC, Gene: gag-pol
# Percentages of CTACCCATC at key (3266, 'CTGCCCATA'):
#   Class C: 51.00%
#   Class D: 1.61%
#   Class 11_cpx: 4.76%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGCCTTC, Gene: env
# Percentages of GCTGCCTTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 4.00%
#   Class G: 1.49%
#   Class A6: 64.00%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTCTGTTC, Gene: env
# Percentages of GCTCTGTTC at key (1549, 'GCTTTGTTC'):
#   Class B: 10.00%
#   Class D: 1.61%
#   Class F1: 42.11%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTGCTC, Gene: env
# Percentages of GCTGTGCTC at key (1549, 'GCTTTGTTC'):
#   Class C: 8.00%
#   Class F1: 3.51%
#   Class 11_cpx: 38.10%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTACTC, Gene: env
# Percentages of GCTGTACTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 2.00%
#   Class A1: 1.00%
#   Class C: 10.00%
#   Class 11_cpx: 38.10%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTGTTC, Gene: env
# Percentages of GCTGTGTTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 1.00%
#   Class A1: 1.00%
#   Class B: 22.00%
#   Class G: 1.49%
#   Class C: 52.00%
#   Class D: 35.48%
#   Class F1: 10.53%
#   Class 35_A1D: 66.67%
#   Class 08_BC: 83.33%
#   Class 11_cpx: 4.76%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTATGTTC, Gene: env
# Percentages of GCTATGTTC at key (1549, 'GCTTTGTTC'):
#   Class B: 41.00%
#   Class C: 2.00%
#   Class D: 46.77%
#   Class F1: 5.26%
#   Class 35_A1D: 19.05%
#   Class 08_BC: 10.00%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTCTTC, Gene: env
# Percentages of GCTGTCTTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 57.00%
#   Class A1: 33.00%
#   Class G: 43.28%
#   Class 20_BG: 7.69%
#   Class 63_02A6: 61.54%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: ATGCTATTC, Gene: env
# Percentages of ATGCTATTC at key (1549, 'GCTTTGTTC'):
#   Class O: 89.66%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTTTTC, Gene: env
# Percentages of GCTGTTTTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 4.00%
#   Class A1: 35.00%
#   Class G: 10.45%
#   Class F1: 1.75%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTGTCCTC, Gene: env
# Percentages of GCTGTCCTC at key (1549, 'GCTTTGTTC'):
#   Class 02_AG: 9.00%
#   Class A1: 8.00%
#   Class G: 8.96%
#   Class 20_BG: 92.31%
#   Class 63_02A6: 3.85%
#
# K-mer variations: ['GCTGCCTTC', 'GCTCTGTTC', 'GCTGTGCTC', 'GCTGTACTC', 'GCTGTGTTC', 'GCTATGTTC', 'GCTGTCTTC', 'ATGCTATTC', 'GCTGTTTTC', 'GCTGTCCTC', 'GCTATGATC'], Key: (1549, 'GCTTTGTTC'), K-mer: GCTATGATC, Gene: env
# Percentages of GCTATGATC at key (1549, 'GCTTTGTTC'):
#   Class 01_AE: 81.00%
#   Class C: 1.00%
